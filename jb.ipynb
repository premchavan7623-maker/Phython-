# %%
r1=float(input("R1="))
r2=float(input("R2="))
rs=r1+r2
print(rs)
# Out:
# R1= 2
# R2= 2
# 4.0

# %%
R1=float(input("R1="))
R2=float(input("R2="))
Rp=1/(1/R1)+(1/R2)
print(Rp)
# Out:
# R1= 2
# R2= 2
# 2.5

# %%
i=20
r=90
v=i*r
print(v)
# Out:
# 1800

# %%
R1 = float(input("R1: "))
R2 = float(input("R2: "))
Rs = R1 + R2
print(Rs)
# Out:
# R1:  2
# R2:  3
# 5.0

# %%
I = float(input("I: "))
R = float(input("R: "))
V = I * R
print(V)
# Out:
# I:  2
# R:  3
# 6.0
